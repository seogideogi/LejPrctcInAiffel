# %% [markdown]
# # 1-3 간단한 그래프 그리기(1) 막대그래프

# %% [markdown]
# # 모듈을 import 하고 그래프로 그릴 데이터를 정의

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %matplotlib inline은 IPython에서 사용하는 매직 메서드에요. Rich output에 대한 표현 방식

# %%
# 그래프 데이터
subject =['English', 'Math', 'Korean', 'Science', 'Computer']
points=[40, 90, 50, 60, 100]

# %% [markdown]
# # 축 그리기

# %%
fig = plt.figure() # 도화지 객체
ax1= fig.add_subplot(1,1,1) # 축을 그려줌 , 아규먼트는 그래프의 사이즈

# %%
fig = plt.figure() # 도화지 객체
# 만 실행하면, 나오는 out 은 없으나, 객체는 생성 됨.

# %%
fig = plt.figure(figsize = (5,6))  ## 도화지 사이즈 지정
ax1 = fig.add_subplot(1,1,1)
'''
Three integers (nrows, ncols, index). 
The subplot will take the index position on a grid with nrows rows 
and ncols columns. 
index starts at 1 in the upper left corner and increases to the right.
'''
# Out:
# '\nThree integers (nrows, ncols, index). \nThe subplot will take the index position on a grid with nrows rows \nand ncols columns. \nindex starts at 1 in the upper left corner and increases to the right.\n'

# %% [markdown]
# # 그래프 위치 부여

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2,2,1) # 2*2 의 칸에 1번 위치
ax2 = fig.add_subplot(2,2,2) # 2*2 의 칸에 2번 위치
ax3 = fig.add_subplot(2,2,4) # 2*2 의 칸에 4번 위치

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2,3,1)  # 행수 , 열수, 자리번호
ax2 = fig.add_subplot(2,3,4)
ax3 = fig.add_subplot(2,3,5)
ax4 = fig.add_subplot(2,3,6)

# %% [markdown]
# # 그래프 그리기

# %%
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
ax1.bar(subject, points)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # 그래프 요소 추가
#
# x라벨 - xlabel()
#
# y라벨 - ylabel()
#
# 제목  - title()

# %%
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

ax1.bar(subject, points)

plt.xlabel('Subject')  
plt.ylabel('Points')  
plt.title("score")
# Out:
# Text(0.5, 1.0, 'score')

# %% [markdown]
# # 1-4 간단한 그래프 그리기(2) 선그래프

# %% [markdown]
# 내 작업 디렉토리에 data 폴더 심볼릭 링크 만들고 아래 수행
# ln -s ~/data .

# %%
from datetime import datetime
import pandas as pd
import os

# 그래프 데이터 
csv_path = os.getenv("HOME") + "/data/AMZN.csv"
data = pd.read_csv(csv_path, index_col=0, parse_dates=True)

# %%
data.info()
data # data가 행이름으로 지정되어 있음.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2019-03-25 to 2020-03-20
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       251 non-null    float64
#  1   High       251 non-null    float64
#  2   Low        251 non-null    float64
#  3   Close      251 non-null    float64
#  4   Adj Close  251 non-null    float64
#  5   Volume     251 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.7 KB
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-03-25  1757.790039  1782.680054  1747.500000  1774.260010  1774.260010
# 2019-03-26  1793.000000  1805.770020  1773.359985  1783.760010  1783.760010
# 2019-03-27  1784.130005  1787.500000  1745.680054  1765.699951  1765.699951
# 2019-03-28  1770.000000  1777.930054  1753.469971  1773.420044  1773.420044
# 2019-03-29  1786.579956  1792.859985  1776.630005  1780.750000  1780.750000
# ...

# %%
price = data['Close'] # 파일에서 시리즈 뽑아 저장

# 축 그리기 및 좌표축 설정
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

price.plot(ax=ax, style='black')

plt.ylim([1600, 2200]) # 한계지정
plt.xlim(['2019-05-01', '2020-03-01']) # 한계지정

# 주석달기  - annotate ()
important_data = [(datetime(2019, 6, 3), "Low Price"), (datetime(2020, 2, 19), "Peak Price")]

for d, label in important_data:
    ax.annotate(label, xy=(d, price.asof(d)+10), # 주석을 달 좌표(x,y)
                xytext=(d, price.asof(d)+100), # 주석 텍스트가 위치할 좌표(x,y)
                arrowprops=dict(facecolor='red')) # 화살표 추가 및 색 설정

# 그리드, 타이틀 달기
plt.grid()
ax.set_title('StockPrice')

# 보여주기
plt.show()

# %% [markdown]
# 그리드 - 격자 눈금 추가

# %%
# Q. 날짜별 종가(Close)가 아닌 최고가(High) 데이터를 이용해서 위와 같은 그래프를 그려보세요!
# 그래프 데이터 
csv_path = os.getenv("HOME") + "/data/AMZN.csv"
data = pd.read_csv(csv_path, index_col=0, parse_dates=True)
price = data['High']

# 축 그리기 및 좌표축 설정
fgr = plt.figure()
ax =  fgr.add_subplot(1,1,1)

price.plot(ax=ax, style='black')

# 날짜 정보를 python datetime 자료형으로 변환
min_date = price.idxmin().to_pydatetime()
max_date = price.idxmax().to_pydatetime()

# 주석달기
important_data = [(min_date, "Low Price"), (max_date, "Peak Price")]

for d, label in important_data :
    ax.annotate( label, xy=(d, price.asof(d) + 10) ,
                xytext = (d, price.asof(d) + 100) ,
                arrowprops = dict(facecolor ='red') )

# 그리드, 타이틀 달기
plt.grid()
ax.set_title('Stock Price (High)')

# 보여주기
plt.show()

# %% [markdown]
# # 1-5 간단한 그래프 그리기(3) - plot 사용법 상세
# plt.plot()로 그래프 그리기
#
# plt.plot() 함수로 그래프를 그리면 matplotlib은 가장 최근의 figure 객체와 그 subplot 을 add 함.
#
# 만약 서브플롯이 없으면 서브플롯 하나를 생성 한다.
#
#
# plt.plot()의 인자로 x 데이터, y 데이터, 마커 옵션, 색상 등을 지정

# %%
import numpy as np

x  = np.linspace( 0, 10, 100 )

plt.plot(x, np.sin(x), 'o') # r, g , b 라고 각각  주니까 색이 바뀜
plt.plot(x, np.cos(x), '--', color='black')
plt.show()

# %% [markdown]
# subplot 추가   -   plt.subplot()

# %%
x = np.linspace( 0, 10, 100)

plt.subplot(2,1,1)
plt.plot(x, np.sin(x), 'o', color ='orange')

plt.subplot(2,1,2)
plt.plot(x, np.cos(x), 'orange')
plt.show()

# %% [markdown]
# line style , marker 옵션

# %%
x = np.linspace(0, 10, 100) 

plt.plot(x, x + 0, linestyle='solid') 
plt.plot(x, x + 1, linestyle='dashed') 
plt.plot(x, x + 2, linestyle='dashdot') 
plt.plot(x, x + 3, linestyle='dotted')
plt.plot(x, x + 0, '-g') # solid green 
plt.plot(x, x + 1, '--c') # dashed cyan 
plt.plot(x, x + 2, '-.k') # dashdot black 
plt.plot(x, x + 3, ':r'); # dotted red
plt.plot(x, x + 4, linestyle='-') # solid 
plt.plot(x, x + 5, linestyle='--') # dashed 
plt.plot(x, x + 6, linestyle='-.') # dashdot 
plt.plot(x, x + 7, linestyle=':'); # dotted

# %% [markdown]
# Pandas로 그래프 그리기
#
# pandas.plot 메서드 인자
# * label: 그래프의 범례 이름
# * ax: 그래프를 그릴 matplotlib의 서브플롯 객체
# * style: matplotlib에 전달할 'ko--'같은 스타일의 문자열
# * alpha: 투명도 (0 ~1)
# * kind: 그래프의 종류: line, bar, barh, kde
# * logy: Y축에 대한 로그 스케일
# * use_index: 객체의 색인을 눈금 이름으로 사용할지의 여부
# * rot: 눈금 이름을 로테이션(0 ~ 360)
# * xticks, yticks: x축, y축으로 사용할 값
# * xlim, ylim: x축, y축 한계
# * grid: 축의 그리드 표시할지 여부
#
#
# pandas의 data가 DataFrame 일 때 plot 메서드 인자
# * subplots: 각 DataFrame의 칼럼(column)을 독립된 서브플롯에 그립니다.
# * sharex: subplots=True면 같은 X축을 공유하고 축의 범위와 눈금을 연결합니다.
# * sharey: subplots=True면 같은 Y축을 공유합니다.
# * figsize: 그래프의 크기를 지정합니다. (튜플)
# * title: 그래프의 제목을 지정합니다. (문자열)
# * sort_columns: 칼럼을 알파벳 순서로 그립니다.

# %%
fig , axes = plt.subplots(2,1)
data = pd.Series(np.random.rand(5), index=list('abcde'))
data.plot(kind = 'bar', ax = axes[0], color='blue', alpha = 1)
data.plot(kind = 'barh', ax=axes[1], color='red', alpha = 0.3)
plt.show()

# %% [markdown]
# 선 그래프

# %%
df = pd.DataFrame(np.random.rand( 6,4) , columns = pd.Index(['A', 'B', 'C', 'D']) )
df.plot(kind = 'line')
plt.show()

# %% [markdown]
# plt.savefig 메서드를 이용해 저장.

# %% [markdown]
# # 1-8 , 1-9
#
# 머신러닝_day1_1106_pblc_part.ipynb   파일 참고

# %% [markdown]
# # 1-10 시계열 데이터 시각화 하기

# %%
from datetime import datetime
import pandas as pd
import seaborn as sns

import os

csv_path = os.getenv("HOME") + "/data/flights.csv"
data = pd.read_csv(csv_path)
flights = pd.DataFrame(data)
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %% [markdown]
# 1) 그래프 그리기

# %%
sns.barplot(data=flights, x='year', y='passengers')  # 막대그래프
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.pointplot(data=flights, x='year', y='passengers')  # 점 그래프
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot( data = flights, x='year' , y='passengers') # 선 그래프
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
# 달로 나누어 보기
sns.lineplot( data = flights , x ='year', y='passengers' , hue ='month', palette='ch:50')
plt.legend(bbox_to_anchor=(1.03, 1), loc=2) #legend 그래프 밖에 추가하기

# %%
sns.histplot( flights['passengers'])  ## 히스토그램
# Out:
# <AxesSubplot:xlabel='passengers', ylabel='Count'>

# %% [markdown]
# # 1-11. Heatmap
#
# >❗ 잠깐만! pivot
#
# Heatmap을 그리기 위해 데이터를 pivot 해야 하는 경우가 있습니다.
# pivot이란 어떤 축, 점을 기준으로 바꾸다란 뜻입니다. 데이터 표를 재배치할 때도 pivot이라는 단어를 사용합니다. (엑셀, Database에도 등장하는 용어입니다.)

# %%
# pivot 

pivot = flights.pivot( index ='year', columns='month', values='passengers')
pivot
# Out:
# month  April  August  December  February  January  July  June  March  May  \
# year
# 1949     129     148       118       118      112   148   135    132  121
# 1950     135     170       140       126      115   170   149    141  125
# 1951     163     199       166       150      145   199   178    178  172
# 1952     181     242       194       180      171   230   218    193  183
# 1953     235     272       201       196      196   264   243    236  229
# 1954     227     293       229       188      204   302   264    235  234
# 1955     269     347       278       233      242   364   315    267  270
# 1956     313     405       306       277      284   413   374    317  318
# 1957     348     467       336       301      315   465   422    356  355
# 1958     348     505       337       318      340   491   435    362  363
# 1959     396     559       405       342      360   548   472    406  420
# 1960     461     606       432       391      417   622   535    419  472
#
# ...

# %%
# heatmap
sns.heatmap(pivot)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.heatmap( pivot, linewidths =.2 , annot=True, fmt='d')
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %% [markdown]
# - `linewidths = .2`: 각 셀 사이의 선 너비를 설정하는 값으로, 셀 경계의 두께를 결정하여 셀을 더 분명하게 구분할 수 있음
# - `annot=True`: 각 셀에 데이터 값을 주석으로 표시할지 여부를 결정하며, True로 설정하면 각 셀에 해당 데이터 값이 표시됨
# - `fmt='d'`: 셀 안에 표시될 숫자의 포맷을 결정하는 값으로, `'d'`를 사용하면 정수형으로 표시됨.  필요에 따라 소수점 형식으로 변경하려면 'f' 등을 사용할 수 있음.

# %%
sns.heatmap( pivot, linewidths =.2 , annot=True, fmt='d' , cmap='YlGnBu')  # 엘로우 그린 블루 .. 인듯
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %% [markdown]
# # 종합퀴즈

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

tips = sns.load_dataset("tips")

# %%
# Q. 시간대(time)에 따른 tip과 total_bill의 관계를 scatter plot으로 시각화해봅시다.
plt.figure()
sns.scatterplot (data = tips, x= 'total_bill', y='tip', hue='time')

plt.xlabel('total_bill')
plt.ylabel('tip')

plt.show()

# %%
# Q. seaborn jointplot의 문서를 참고하여 아래와 같은 그래프를 그려보세요!
sns.jointplot(data=tips, x='total_bill', y='tip', hue='time', kind="scatter")  #kind="kde" or kind="reg" 추가 가능

plt.show()
