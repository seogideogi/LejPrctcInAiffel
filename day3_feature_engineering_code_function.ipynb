# %% [markdown]
# # 5-6 실무팁 ( Code Function )
# 피처엔지니어링 작업을 함수화 하여, 선형적 작업을 최소화 한다.

# %% [markdown]
# func

# %%
##def add_ten(x) :
##    return x + 10

# %%
##add_ten(5)

# %% [markdown]
# src 디렉토리 생성 하고 다시 소스로 돌아와서.

# %%
# 위 함수 script 변수에 저장
script ="""
def add_ten(x) :
    return x + 10
"""

# %%
script
# Out:
# '\ndef add_ten(x) :\n    return x + 10\n'

# %%
filename = "./src/add_ten.py"   # ./ 현재폴더 아래       src 라는 디렉토리 안에    add_ten.py    로 저장.

# %%
# 파일로 생성하기
with open (filename, 'w') as file :
    file.write(script)

# %% [markdown]
# src  디렉토리에 add_ten.py 생성 된 것 확인.
#
# test 파일에서 아래와 같이 작성.

# %%
import sys

# %%
sys.path.append('./src') # 현재 디렉토리 안의 src 패스 설정

# %%
from add_ten import add_ten # ( from 파일명 import 함수명)

# %%
add_ten(3)
# Out:
# 13

# %%
## func 주피터노트북 파일 외부에서 생성, 그곳에 작성

# %%
## test 내용

# %%
import sys
import pandas as pd
import numpy as np

# %%
sys.path.append('./src')

# %%
dating_df = pd.read_csv('~/data/dating.csv') # new_dating.csv 라는 파일 없음

# %% [markdown]
# # 컬럼이름 변경

# %%
from col_rename import col_rename

# %%
dating_df = col_rename(dating_df)

# %% [markdown]
# # 결측치 처리

# %%
from missing_func import missing_func

# %%
dating_df = missing_func(dating_df)

# %% [markdown]
# # 이상치(Outlier) 처리

# %% [markdown]
# score 부분, 10으로 값 맞추기

# %%
from outlier_func import outlier_func

# %%
dating_df = outlier_func(dating_df)

# %%
pd.set_option('display.max_columns', 99)

# %%
dating_df.describe() # score max 10 적용 확인
# Out:
#                age        age_o  importance_same_race  \
# count  8130.000000  8130.000000           8130.000000
# mean     26.034932    26.034932              3.776753
# std       7.418562     7.418562              2.844297
# min     -99.000000   -99.000000              0.000000
# 25%      24.000000    24.000000              1.000000
# 50%      26.000000    26.000000              3.000000
# 75%      28.000000    28.000000              6.000000
# max      55.000000    55.000000             10.000000
#
#        importance_same_religion  o_important_attractive  o_important_sincere  \
# count               8130.000000             8130.000000          8130.000000
# mean                   3.658303               22.320451            17.433629
# std                    2.807314               12.398470             7.017378
# min                    1.000000                0.000000             0.000000
# 25%                    1.000000               15.000000            15.000000
# ...

# %% [markdown]
# important 부분 가중치 적용, 100 으로 값 맞추기

# %%
from imp_func import imp_func

# %%
dating_df = imp_func(dating_df)

# %% [markdown]
# Age 나이차 처리

# %%
from age_gap_func import age_gap_func

# %%
dating_df = age_gap_func(dating_df)

# %%
dating_df.head()
# Out:
#    gender   age  age_o                                  race  \
# 0  female  21.0   27.0  Asian/PacificIslander/Asian-American
# 1  female  21.0   22.0  Asian/PacificIslander/Asian-American
# 2  female  21.0   22.0  Asian/PacificIslander/Asian-American
# 3  female  21.0   23.0  Asian/PacificIslander/Asian-American
# 4  female  21.0   24.0  Asian/PacificIslander/Asian-American
#
#                                  race_o  importance_same_race  \
# 0           European/Caucasian-American                   2.0
# 1           European/Caucasian-American                   2.0
# 2  Asian/PacificIslander/Asian-American                   2.0
# 3           European/Caucasian-American                   2.0
# 4               Latino/HispanicAmerican                   2.0
#
#    importance_same_religion  o_important_attractive  o_important_sincere  \
# 0                       4.0                    35.0                 20.0
# 1                       4.0                    60.0                  0.0
# ...

# %% [markdown]
# 인종 처리

# %%
from race_func import race_func

# %%
dating_df = race_func(dating_df)

# %%
dating_df.head()
# Out:
#    gender   age  age_o                                  race  \
# 0  female  21.0   27.0  Asian/PacificIslander/Asian-American
# 1  female  21.0   22.0  Asian/PacificIslander/Asian-American
# 2  female  21.0   22.0  Asian/PacificIslander/Asian-American
# 3  female  21.0   23.0  Asian/PacificIslander/Asian-American
# 4  female  21.0   24.0  Asian/PacificIslander/Asian-American
#
#                                  race_o  importance_same_race  \
# 0           European/Caucasian-American                   2.0
# 1           European/Caucasian-American                   2.0
# 2  Asian/PacificIslander/Asian-American                   2.0
# 3           European/Caucasian-American                   2.0
# 4               Latino/HispanicAmerican                   2.0
#
#    importance_same_religion  o_important_attractive  o_important_sincere  \
# 0                       4.0                    35.0                 20.0
# 1                       4.0                    60.0                  0.0
# ...

# %% [markdown]
# # 5-4 평가(Rating) 관련 피처 생성 및 활용

# %%
from rating_func import rating_func

# %%
dating_df = rating_func(dating_df)

# %%
dating_df.head()
# Out:
#    gender   age  age_o                                  race  \
# 0  female  21.0   27.0  Asian/PacificIslander/Asian-American
# 1  female  21.0   22.0  Asian/PacificIslander/Asian-American
# 2  female  21.0   22.0  Asian/PacificIslander/Asian-American
# 3  female  21.0   23.0  Asian/PacificIslander/Asian-American
# 4  female  21.0   24.0  Asian/PacificIslander/Asian-American
#
#                                  race_o  importance_same_race  \
# 0           European/Caucasian-American                   2.0
# 1           European/Caucasian-American                   2.0
# 2  Asian/PacificIslander/Asian-American                   2.0
# 3           European/Caucasian-American                   2.0
# 4               Latino/HispanicAmerican                   2.0
#
#    importance_same_religion  o_important_attractive  o_important_sincere  \
# 0                       4.0                    35.0                 20.0
# 1                       4.0                    60.0                -99.0
# ...

# %% [markdown]
# 원하는 컬럼 추리기, 원핫 인코딩

# %%
from sel_one_func import sel_one_func

# %%
dating_df = sel_one_func(dating_df)

# %%
dating_df.head()
# Out:
#     age  interests_correlate  expected_happy_with_sd_people  \
# 0  21.0                 0.14                            3.0
# 1  21.0                 0.54                            3.0
# 2  21.0                 0.16                            3.0
# 3  21.0                 0.61                            3.0
# 4  21.0                 0.21                            3.0
#
#    expected_num_interested_in_me  like  guess_prob_liked  age_gap  \
# 0                            2.0   7.0               6.0      6.0
# 1                            2.0   7.0               5.0      1.0
# 2                            2.0   7.0             -99.0      1.0
# 3                            2.0   7.0               6.0      2.0
# 4                            2.0   6.0               6.0      3.0
#
#    same_race_point  o_rating_attractive  o_rating_sincere  \
# 0             -2.0                210.0             160.0
# 1             -2.0                420.0             -99.0
# ...

# %% [markdown]
# # 위 ### import 부분들 func에 몰아 넣기

# %%
import sys
import pandas as pd
import numpy as np

# %%
sys.path.append('./src') # 현재 디렉토리 안의 src 패스 설정

# %%
dating_df = pd.read_csv('~/data/dating.csv') # new_dating.csv 라는 파일 없음

# %%
from pre_func import pre_func

# %%
pre_func(dating_df)
# Out:
#        age  interests_correlate  expected_happy_with_sd_people  \
# 0     21.0                 0.14                            3.0
# 1     21.0                 0.54                            3.0
# 2     21.0                 0.16                            3.0
# 3     21.0                 0.61                            3.0
# 4     21.0                 0.21                            3.0
# ...    ...                  ...                            ...
# 8372  25.0                 0.28                           10.0
# 8373  25.0                 0.64                           10.0
# 8374  25.0                 0.71                           10.0
# 8376  25.0                 0.62                           10.0
# 8377  25.0                 0.01                           10.0
#
#       expected_num_interested_in_me  like  guess_prob_liked  age_gap  \
# 0                               2.0   7.0               6.0      6.0
# ...
